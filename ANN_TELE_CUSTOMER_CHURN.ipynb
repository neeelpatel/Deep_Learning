# %%
#import dataset
import pandas as pd
import os

# %%
os.chdir("F:\\neel\\fingertips\\Deep Learning")

# %%
data=pd.read_csv('tele_customer_churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.drop('customerID',axis='columns',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
data.TotalCharges.unique
# Out:
# <bound method Series.unique of 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object>

# %%
#check null value
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data[data['TotalCharges'] == " "]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
data[data['TotalCharges'] == " "].index
# Out:
# Int64Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
#here we can say that totalcharges have some balnk value in records
data.drop(data[data['TotalCharges'] == " "].index,inplace=True)

# %%
data[data['TotalCharges'] == " "].index
# Out:
# Int64Index([], dtype='int64')

# %%
#convert totalcharge into numeric
data.TotalCharges=pd.to_numeric(data.TotalCharges)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
#all the columns with unique value
for column in data:
    print(f'{column} : {data[column].unique()}')
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# tenure : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# ...

# %%
for column in data:
    if data[column].dtypes=='object':
         print(f'{column} : {data[column].unique()}')
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %% [markdown]
# here no internet service means no so replace no internet service with no

# %%
data.replace('No internet service','No',inplace=True)

# %%
for column in data:
    if data[column].dtypes=='object':
         print(f'{column} : {data[column].unique()}')
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %% [markdown]
# similarly replace no phone service with no

# %%
data.replace('No phone service','No',inplace=True)

# %%
data.MultipleLines.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#convert categorical value into numeric
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
data[['gender','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']] = data[['gender','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']].apply(labelencoder.fit_transform)

# %%
for column in data:
    print(f'{column}:{data[column].unique()}')
# Out:
# gender:[0 1]
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# DeviceProtection:[0 1]
# TechSupport:[0 1]
# StreamingTV:[0 1]
# StreamingMovies:[0 1]
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:[1 0]
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges:[29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges:[  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn:['No' 'Yes']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   int32
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   int32
#  3   Dependents        7032 non-null   int32
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   int32
#  6   MultipleLines     7032 non-null   int32
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   int32
#  9   OnlineBackup      7032 non-null   int32
#  10  DeviceProtection  7032 non-null   int32
#  11  TechSupport       7032 non-null   int32
#  12  StreamingTV       7032 non-null   int32
#  13  StreamingMovies   7032 non-null   int32
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   int32
# ...

# %%
data=pd.get_dummies(data=data,columns=['InternetService','Contract','PaymentMethod'],drop_first=True)

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 7032 non-null   int32
#  1   SeniorCitizen                          7032 non-null   int64
#  2   Partner                                7032 non-null   int32
#  3   Dependents                             7032 non-null   int32
#  4   tenure                                 7032 non-null   int64
#  5   PhoneService                           7032 non-null   int32
#  6   MultipleLines                          7032 non-null   int32
#  7   OnlineSecurity                         7032 non-null   int32
#  8   OnlineBackup                           7032 non-null   int32
#  9   DeviceProtection                       7032 non-null   int32
#  10  TechSupport                            7032 non-null   int32
# ...

# %%
data['Churn']=labelencoder.fit_transform(data['Churn'])

# %%
data.Churn.unique()
# Out:
# array([0, 1])

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
#scalling
from sklearn.preprocessing import MinMaxScaler
model = MinMaxScaler()
data[['tenure','MonthlyCharges','TotalCharges']]=model.fit_transform(data[['tenure','MonthlyCharges','TotalCharges']])

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0          0              0        1           0  0.000000             0
# 1          1              0        0           0  0.464789             1
# 2          1              0        0           0  0.014085             1
# 3          1              0        0           0  0.619718             0
# 4          0              0        0           0  0.014085             1
# ...      ...            ...      ...         ...       ...           ...
# 7038       1              0        1           1  0.323944             1
# 7039       0              0        1           1  1.000000             1
# 7040       0              0        1           1  0.140845             0
# 7041       1              1        1           0  0.042254             1
# 7042       1              0        0           0  0.915493             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
#dependent and independent data
x=data.drop(['Churn'],axis='columns')
y=data['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (4922, 23)

# %%
#create ANN ,initializing model
classifier = keras.Sequential()
#adding inputlayer,here we have 24 columns as a feature
classifier.add(Dense(units=20,activation="relu",input_shape=(23,)))
#add secound layer
classifier.add(Dense(units=15,activation='relu'))
#add another hidden layer
classifier.add(Dense(units=10,activation="relu"))
classifier.add(Dense(units=1,activation="sigmoid"))

# %%
#train model
classifier.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
model = classifier.fit(x_train,y_train,validation_split=0.33,epochs=100)
# Out:
# Epoch 1/100
# 104/104 [==============================] - 0s 5ms/step - loss: 0.3216 - accuracy: 0.8547 - val_loss: 0.4943 - val_accuracy: 0.7951
# Epoch 2/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.3182 - accuracy: 0.8611 - val_loss: 0.4925 - val_accuracy: 0.7945
# Epoch 3/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.3199 - accuracy: 0.8556 - val_loss: 0.4873 - val_accuracy: 0.7883
# Epoch 4/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.3209 - accuracy: 0.8532 - val_loss: 0.4870 - val_accuracy: 0.7871
# Epoch 5/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.3164 - accuracy: 0.8587 - val_loss: 0.4862 - val_accuracy: 0.7932
# Epoch 6/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.3157 - accuracy: 0.8593 - val_loss: 0.4868 - val_accuracy: 0.7895
# Epoch 7/100
# ...

# %%
#evalute model 
classifier.evaluate(x_test,y_test)
# Out:
# 66/66 [==============================] - 0s 2ms/step - loss: 0.6063 - accuracy: 0.7536
# [0.6062821745872498, 0.7535545229911804]

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# 66/66 [==============================] - 0s 2ms/step
# array([[4.5925356e-02],
#        [1.1071949e-01],
#        [6.0246843e-03],
#        ...,
#        [8.2875643e-04],
#        [9.6217775e-01],
#        [1.8372636e-02]], dtype=float32)

# %% [markdown]
# here, problem is we get two dimension array so we need to convert it into one dimenstion array.
#
# and in y_test we have o and 1 only so we need to convert y_pred into one dimention
#
# if y_pred > 0.5 then convert it into 1 other wise convert it into 0

# %%
yp= []
for i in y_pred:
    if i > 0.5:
        yp.append(1)
    else:
        yp.append(0)

# %%
yp[:5]
# Out:
# [0, 0, 0, 1, 1]

# %%
y_test[:5]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# Name: Churn, dtype: int32

# %%
#confussion_matrix,classification_repot
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print(classification_report(yp,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      1575
#            1       0.51      0.57      0.54       535
#
#     accuracy                           0.75      2110
#    macro avg       0.68      0.69      0.69      2110
# weighted avg       0.76      0.75      0.76      2110

# %%
accuracy_score(y_test,yp)
# Out:
# 0.7535545023696683
